# %% [markdown]
#   ## Happiness Score

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# #### Dystopia

# %% [markdown]
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# #### Residual
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.

# %%
import pandas as pd
df = pd.read_csv('happiness_score.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ## About columns
#
# 1. Country
#
# The list of country based on the happiness score where the survey was conducted
#
# 2. Region
#
# This shows the list of regions across the globe who were the part of the survey
#
# 3. Happiness Rank
#
# Based on the happiness score the countries were rated from highest to the lowest score
#
# 4. Happiness Score
#
# This column defines the score achieved by each country based on the factors like Economy, Trust, Generosity etc.
# The higher is the value of the factors, the higher is the score.
#
# 5. Standard Error
#
# This defines the error rate in the survey
#
# 6. Economy(GDP per Capita)
#
# This shows the Economy rate in GDP per Capita
#
# 7. Family
#
# This shows the number of families count
#
# 8. Health(Life Expectancy)
#
# This shows the health of the people in the family
#
# 9. Freedom
#
# This shows the freedom factor which helps to increase the happiness score
#
# 10. Trust(Government Corruption)
#
# This shows the level of Trust in the people
#
# 11. Generosity
#
# This shows the percentage of generosity
#
# 12. Dystopia Residual
#
# This shows the residual score

# %%
df.drop(['Country','Region'],axis=1)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Family',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Rank',y='Happiness Score',data = df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %% [markdown]
# ### Correlation

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.drop(['Country','Region'],axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,30))
sns.heatmap(df,annot=True,linewidth=10,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:],2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variables')
plt.show()

# %% [markdown]
# ### Outcome of Describe of DataSets:
#
# From the above plotting we are determining mean, Standard Deviation,Maximum and Minimum values of each column. It helps in further cleaning of data.
#
# Total Number of rows in Datasets:
#    1. 158
#    2. 10
#
# Happiness Rank:
#    1. Mean = 79.49
#    2. STD  = 45.75
#    3. Min  = 1
#    4. Max  = 158
#
# Happiness Score:
#    1. Mean = 5.38
#    2. STD  = 1.15
#    3. Min  = 2.84
#    4. Max  = 7.59
#
# Standard Error:
#    1. Mean = 0.05
#    2. STD  = 0.02
#    3. Min  = 0.02
#    4. Max  = 1.69
#
# Economy(GDP per Capita):
#    1. Mean = 0.85
#    2. STD  = 0.40
#    3. Min  = 0
#    4. Max  = 1.40
#
# Family
#    1. Mean = 0.99
#    2. STD  = 0.27
#    3. Min  = 0.00
#    4. Max  = 1.40
#
# Health(Life Expenctancy)
#    1. Mean = 0.63
#    2. STD  = 0.25
#    3. Min  = 0.00
#    4. Max  = 1.03
#
# Freedom:
#    1. Mean = 0.43
#    2. STD  = 0.15
#    3. Min  = 0.00
#    4. Max  = 0.67
#
# Trust(Government Corruption):
#    1. Mean = 0.14
#    2. STD  = 0.12
#    3. Min  = 0.00
#    4. Max  = 0.55
#
# Generosity:
#    1. Mean = 0.24
#    2. STD  = 0.13
#    3. Min  = 0
#    4. Max  = 0.80
#
# Dystopia Residual:
#    1. Mean = 2.10
#    2. STD  = 0.55
#    3. Min  = 0.33
#    4. Max  = 3.60

# %% [markdown]
# ## Outliers Checking

# %%
collist=df.columns.values
ncol=20
nrows=15
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(ncol,nrows,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# From the outcome we can see that columns['Standard Error','Trust(Government Corruption)'] has more outliers while columns Happiness score has no outliers
# columns['Family','Generosity','Dystopia Residual'] has less outliers

# %% [markdown]
# ## Skewness:

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
Outcome of the skewness is taken as +-/0.1. Columns which are having skewness are
Standard error
Trust
Generosity

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<10:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber +=1
    
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Removing Outliers
# Z-score technique

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %%
loss_percentage = (158-149)/158*100
loss_percentage
# Out:
# 5.69620253164557

# %% [markdown]
# Dividing Data in features and vector

# %%
x = df_new.drop('Happiness Score',axis=1)
y = df_new['Happiness Score']

# %% [markdown]
# #### Transforming data to remove Skewness:

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.05151352, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-1.99584442,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.94524081, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 1.53128908, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 1.56626337, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 1.60111233,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-2.05151352, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-1.99584442,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.94524081, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 1.53128908, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 1.56626337, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 1.60111233,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %% [markdown]
# ### Since Happiness Score has mmore than 2 variables so we will use Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# ### Splitting the dataframe

# %%
for i in range (1,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    if round(lr.score(x_train,y_train)*100) == round(lr.score(x_test,y_test)*100):
        print('At random state',i,' The model perfomed very well')
        print('At random state:-',i)
        print('Training score is:-', lr.score(x_train,y_train))
        print('Test score is:-', lr.score(x_test,y_test))
# Out:
# At random state 1  The model perfomed very well
# At random state:- 1
# Training score is:- 0.9953157355892726
# Test score is:- 0.9969248098774244
# At random state 2  The model perfomed very well
# At random state:- 2
# Training score is:- 0.9953182978903121
# Test score is:- 0.9958525959290531
# At random state 3  The model perfomed very well
# At random state:- 3
# Training score is:- 0.9952897882983827
# Test score is:- 0.9961686570559882
# At random state 12  The model perfomed very well
# At random state:- 12
# Training score is:- 0.9955327610352216
# Test score is:- 0.9953194880783601
# At random state 13  The model perfomed very well
# At random state:- 13
# Training score is:- 0.9954162988320452
# Test score is:- 0.9954479257354952
# At random state 14  The model perfomed very well
# At random state:- 14
# Training score is:- 0.9953324403374942
# Test score is:- 0.9957464383522664
# At random state 15  The model perfomed very well
# At random state:- 15
# ...

# %% [markdown]
# ### Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
lss = lr.score(x_test,y_test)
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc= lsscore.mean()
    print('At cv:-',j)
    print('Cross Validation score is ',lsc*100)
    print('Actual score is ',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross Validation score is  89.51595685241654
# Actual score is  99.29128206102212
#
#
# At cv:- 3
# Cross Validation score is  92.20716764885502
# Actual score is  99.29128206102212
#
#
# At cv:- 4
# Cross Validation score is  87.83983490276772
# Actual score is  99.29128206102212
#
#
# At cv:- 5
# Cross Validation score is  84.32701868104544
# Actual score is  99.29128206102212
#
#
# At cv:- 6
# Cross Validation score is  77.03451648766385
# Actual score is  99.29128206102212
#
#
# At cv:- 7
# Cross Validation score is  70.21624697989375
# Actual score is  99.29128206102212
#
#
# At cv:- 8
# Cross Validation score is  66.7256411971282
# Actual score is  99.29128206102212
#
#
# At cv:- 9
# Cross Validation score is  61.16124602446548
# Actual score is  99.29128206102212

# %% [markdown]
# ### The model with the Outliers

# %% [markdown]
# ### Ploting the Data

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([7.2847783 , 7.41044893, 3.77610289, 6.11230586, 5.43630354,
#        4.28962711, 7.45076941, 7.15131234, 7.36783043, 4.73592947,
#        4.43110296, 5.68914387, 3.37977659, 6.34982779, 6.47168517,
#        6.08577235, 6.45104332, 4.71025024, 5.87748202, 5.31278319,
#        4.99648543, 7.22922334, 4.48962971, 4.86727472, 4.6031672 ,
#        5.03745836, 6.10929643, 4.32344715, 4.07196357, 3.78357227])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Happiness Score')
plt.ylabel('Predicted Happiness Score')
plt.title('Actual vs Model Predicted')
plt.show()

# %% [markdown]
# ## Saving the File

# %%
import pickle
filename = 'happiness.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# ### Conclusion

# %%
import numpy as np
a = np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com = pd.DataFrame({'Original':a,'Predicted':predicted})
df_com
# Out:
#     Original  Predicted
# 0      7.284   7.284778
# 1      7.406   7.410449
# 2      3.575   3.776103
# 3      6.123   6.112306
# 4      5.429   5.436304
# 5      4.350   4.289627
# 6      7.427   7.450769
# 7      7.119   7.151312
# 8      7.378   7.367830
# 9      4.694   4.735929
# 10     4.518   4.431103
# 11     5.689   5.689144
# 12     2.905   3.379777
# 13     6.295   6.349828
# 14     6.477   6.471685
# 15     5.984   6.085772
# 16     6.329   6.451043
# 17     4.786   4.710250
# 18     5.878   5.877482
# 19     5.332   5.312783
# 20     5.013   4.996485
# 21     7.286   7.229223
# 22     4.512   4.489630
# 23     4.885   4.867275
# 24     4.565   4.603167
# 25     4.971   5.037458
# 26     6.130   6.109296
# 27     4.369   4.323447
# 28     4.077   4.071964
# 29     3.781   3.783572
